# %% [markdown]
# <a href="https://colab.research.google.com/github/kamsolek/machine-learning-bootcamp/blob/main/supervised/01_basics/03_feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### scikit-learn
# Strona biblioteki: [https://scikit-learn.org](https://scikit-learn.org)
#
# Dokumentacja/User Guide: [https://scikit-learn.org/stable/user_guide.html](https://scikit-learn.org/stable/user_guide.html)
#
# Podstawowa biblioteka do uczenia maszynowego w języku Python.
#
# Aby zainstalować bibliotekę scikit-learn, użyj polecenia poniżej:
# ```
# !pip install scikit-learn
# ```
# Aby zaktualizować do najnowszej wersji bibliotekę scikit-learn, użyj polecenia poniżej:
# ```
# !pip install --upgrade scikit-learn
# ```
# Kurs stworzony w oparciu o wersję `0.22.1`
#
# ### Spis treści:
# 1. [Import bibliotek](#0)
# 2. [Załadowanie danych](#1)
# 3. [Utworzenie kopii danych](#2)
# 4. [Generowanie nowych zmiennych](#3)
# 5. [Dyskretyzacja zmiennej ciągłej](#4)
# 6. [Ekstrakcja cech](#5)

# %% [markdown]
# ### <a name='0'></a> Import bibliotek

# %%
import numpy as np
import pandas as pd
import sklearn

sklearn.__version__
# Out:
# '1.6.1'

# %% [markdown]
# ### <a name='1'></a> Załadowanie danych

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetches stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df_raw = fetch_financial_data()
df_raw.head() # head - pięc pierwszych wierszy
# Out:
#               Open      High      Low   Close    Volume
# Date
# 2025-08-25  227.35  229.6000  227.310  227.94  22633695
# 2025-08-22  222.79  229.1400  220.820  228.84  37315341
# 2025-08-21  222.65  222.7800  220.500  221.95  32140459
# 2025-08-20  227.12  227.2700  220.915  223.81  36604319
# 2025-08-19  230.09  230.5283  227.120  228.01  29891012

# %% [markdown]
# ### <a name='2'></a> Utworzenie kopii danych

# %%
df = df_raw.copy()
df = df[:5]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2025-08-25 to 2025-08-19
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5 non-null      float64
#  1   High    5 non-null      float64
#  2   Low     5 non-null      float64
#  3   Close   5 non-null      float64
#  4   Volume  5 non-null      int64
# dtypes: float64(4), int64(1)
# memory usage: 240.0 bytes

# %% [markdown]
# ### <a name='3'></a> Generowanie nowych zmiennych

# %%
df.index.month_name ('en_US.utf8')
# Out:
# Index(['August', 'August', 'August', 'August', 'August'], dtype='object', name='Date')

# %%
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year
df
# Out:
#               Open      High      Low   Close    Volume  day  month  year
# Date
# 2025-08-25  227.35  229.6000  227.310  227.94  22633695   25      8  2025
# 2025-08-22  222.79  229.1400  220.820  228.84  37315341   22      8  2025
# 2025-08-21  222.65  222.7800  220.500  221.95  32140459   21      8  2025
# 2025-08-20  227.12  227.2700  220.915  223.81  36604319   20      8  2025
# 2025-08-19  230.09  230.5283  227.120  228.01  29891012   19      8  2025

# %% [markdown]
# ### <a name='4'></a> Dyskretyzacja zmiennej ciągłej

# %%
df = pd.DataFrame(data={'height': [175., 178.5, 185., 191., 184.5, 183., 168.]})
df
# Out:
#    height
# 0   175.0
# 1   178.5
# 2   185.0
# 3   191.0
# 4   184.5
# 5   183.0
# 6   168.0

# %%
df['height_cat'] = pd.cut(x=df.height, bins=3)
df
# Out:
#    height          height_cat
# 0   175.0  (167.977, 175.667]
# 1   178.5  (175.667, 183.333]
# 2   185.0    (183.333, 191.0]
# 3   191.0    (183.333, 191.0]
# 4   184.5    (183.333, 191.0]
# 5   183.0  (175.667, 183.333]
# 6   168.0  (167.977, 175.667]

# %%
df['height_cat'] = pd.cut(x=df.height, bins=(160, 175, 180, 195))
df
# Out:
#    height  height_cat
# 0   175.0  (160, 175]
# 1   178.5  (175, 180]
# 2   185.0  (180, 195]
# 3   191.0  (180, 195]
# 4   184.5  (180, 195]
# 5   183.0  (180, 195]
# 6   168.0  (160, 175]

# %%
df['height_cat'] = pd.cut(x=df.height, bins=(160, 175, 180, 195), labels=['small', 'medium', 'high'])
df
# Out:
#    height height_cat
# 0   175.0      small
# 1   178.5     medium
# 2   185.0       high
# 3   191.0       high
# 4   184.5       high
# 5   183.0       high
# 6   168.0      small

# %%
df['height_cat'] = pd.cut(x=df.height, bins=3, labels=['small', 'medium', 'high'])
df
# Out:
#    height height_cat
# 0   175.0      small
# 1   178.5     medium
# 2   185.0       high
# 3   191.0       high
# 4   184.5       high
# 5   183.0     medium
# 6   168.0      small

# %%
pd.get_dummies(df, drop_first=True, prefix='height').astype(int)
# Out:
#    height  height_medium  height_high
# 0     175              0            0
# 1     178              1            0
# 2     185              0            1
# 3     191              0            1
# 4     184              0            1
# 5     183              1            0
# 6     168              0            0

# %%
x=pd.get_dummies(df, drop_first=True, prefix='height')
x=x.astype(int)
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# ### <a name='5'></a> Ekstrakcja cech

# %%
df = pd.DataFrame(data={'lang': [['PL', 'ENG'], ['GER', 'ENG', 'PL', 'FRA'], ['RUS']]})
df
# Out:
#                   lang
# 0            [PL, ENG]
# 1  [GER, ENG, PL, FRA]
# 2                [RUS]

# %% [markdown]
# Moje

# %%
date_range = pd.date_range(start='01-01-2020 09:00', end='01-01-2020 18:00', periods=3)
df = pd.DataFrame(data={'lang': [['PL', 'ENG'], ['GER', 'ENG', 'PL', 'FRA'], ['RUS']]},index=date_range)
df
# Out:
#                                     lang
# 2020-01-01 09:00:00            [PL, ENG]
# 2020-01-01 13:30:00  [GER, ENG, PL, FRA]
# 2020-01-01 18:00:00                [RUS]

# %%
df['lang_number'] = df['lang'].apply(len)
df
# Out:
#                                     lang  lang_number
# 2020-01-01 09:00:00            [PL, ENG]            2
# 2020-01-01 13:30:00  [GER, ENG, PL, FRA]            4
# 2020-01-01 18:00:00                [RUS]            1

# %%
df['PL_flag'] = df['lang'].apply(lambda x: 1 if 'PL' in x else 0)
df
# Out:
#                                     lang  lang_number  PL_flag
# 2020-01-01 09:00:00            [PL, ENG]            2        1
# 2020-01-01 13:30:00  [GER, ENG, PL, FRA]            4        1
# 2020-01-01 18:00:00                [RUS]            1        0

# %% [markdown]
# my

# %%
df['PL_flag'] = df['lang'].apply(lambda x: 1 if 'RUS' in x else 0)
df
# Out:
#                                     lang  lang_number  PL_flag
# 2020-01-01 09:00:00            [PL, ENG]            2        0
# 2020-01-01 13:30:00  [GER, ENG, PL, FRA]            4        0
# 2020-01-01 18:00:00                [RUS]            1        1

# %%
df = pd.DataFrame(data={'website': ['wp.pl', 'onet.pl', 'google.com']})
df
# Out:
#       website
# 0       wp.pl
# 1     onet.pl
# 2  google.com

# %%
df.website.str.split('.', expand=True)
# Out:
#         0    1
# 0      wp   pl
# 1    onet   pl
# 2  google  com

# %%
new = df.website.str.split('.', expand=True)
df['portal'] = new[0]
df['extension'] = new[1]
df
# Out:
#       website  portal extension
# 0       wp.pl      wp        pl
# 1     onet.pl    onet        pl
# 2  google.com  google       com
